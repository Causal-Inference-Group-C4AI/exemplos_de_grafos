# %% [markdown]
# # Grafos Causais com Histórias e Informações Detalhadas
#
# ## Grafo 1: **Propagação de uma EpideUMIa**
# ### Contexto:
# Uma doença infecciosa se espalha por uma comunidade. Fatores como vUACinação, comportamento social e condições de saúde influenciam a propagação.
#
# ### Vértices:
# - `D`: Doença (infectados)
# - `V`: VUACinação
# - `C`: Contato social
# - `H`: Higiene pessoal
# - `UA`: Ambiente (não observável)
# - `UI`: Imunidade natural (não observável)
# - `M`: Mídia informativa
# - `S`: Sensação de segurança
# - `P`: Políticas públicas
# - `T`: Testagem
#
# ### Arestas (lista de tuplas):
# ```python
# [
#     ('A', 'D'), ('D', 'C'), ('C', 'D'), ('H', 'D'),
#     ('M', 'V'), ('M', 'S'), ('P', 'V'), ('P', 'H'), ('T', 'D')
# ]
# ```
#
# ### c-components:
# - ``UA``: Ambiente é uma variável não observável que afeta a doença.
# - ``UI``: Imunidade natural é uma variável não observável relUACionada à infecção.

# %%
from utils.funcoes import tuple_generate_example
edges = [
    ('UA', 'D'), ('D', 'C'), ('V', 'I'), ('C', 'D'), ('H', 'D'),
    ('M', 'V'), ('M', 'S'), ('P', 'V'), ('P', 'H'), ('T', 'D')
]
tuple_generate_example(edges)

# %% [markdown]
# ## Grafo 2: **Desempenho UACadêUMIco**
#
# ### Contexto:
# Estudantes têm desempenhos diferentes baseados em fatores UACadêUMIcos, emocionais e sociais.
#
# ### Vértices:
# - `E`: Esforço do aluno
# - `P`: Presença em aula
# - `M`: Métodos de ensino
# - `T`: Tecnologia usada em aula
# - `F`: Fatores externos (não observável)
# - `S`: Suporte faUMIliar
# - `C`: Concentração
# - `H`: Horas de estudo
# - `D`: Desempenho UACadêUMIco
# - `A`: Ansiedade (não observável)
#
# ### Arestas (lista de tuplas):
# ```python
# [
#     ('E', 'D'), ('P', 'E'), ('M', 'D'), ('T', 'M'), ('F', 'C'),
#     ('S', 'E'), ('C', 'E'), ('H', 'E'), ('A', 'C'), ('A', 'D')
# ]
# ```
# ### c-components:
# - `F`: Fatores externos como econoUMIa ou políticas educUACionais.
# - `A`: Ansiedade afeta concentração e desempenho, mas não é diretamente observável.

# %%
edges = [
    ('E', 'D'), ('P', 'E'), ('M', 'D'), ('T', 'M'), ('F', 'C'),
    ('S', 'E'), ('C', 'E'), ('H', 'E'), ('A', 'C'), ('A', 'D')
]
tuple_generate_example(edges)
# Out:
# ('CS', 'RP')

# %%
E1 ="E1"
E2 ="E2"
E3 ="E3"
SF ="SF"
UMI ="UMI"
R ="R"
HT ="HT"
HS ="HS"
EP ="EP"
UAC ="UAC"
UCS ="UCS"
NR = "NR"
URP = "URP"
edges = [
    (E1, E2),
    (E2, E3),
    (E3, R),
    (SF, E1),
    (SF, E2),
    (UMI, R),
    (R, E3),
    (HT, EP),
    (HS, EP),
    (EP, NR),
    (UAC, HT),
    (UAC, HS),
    (UCS, SF),
    (UCS, RP)
    ]
tuple_generate_example(edges)

# %%
from utils.funcoes import tuple_generate_example

AF = "AF"
DB = "DB"
SA = "SA"
SC = "SC"
SM = "SM"
IMC = "IMC"
CA = "CA"
M = "M"
EP = "EP"
UG = "UG"
# URP = "URP"
UFA = "UFA"
SI = "SI"

UCS = "UCS" # Contexto Social
edges = [
(AF, SC),
(AF, IMC),
(DB, IMC),
(DB, SI),
(SA, SM),
(SA, SC),
(SC, SI),
# (SM, M),
(IMC, SC),
(CA, SC),
(CA, SI),
# (M, SI),
(EP, SI),
(EP, SM),
(UG, SC),
(UG, SI),
(UFA, EP),
(UFA, DB),
(UG, SM),
(SM, AF),
(SM, DB),
(SM, CA),
(UCS, AF),
(UCS, SA),
(UCS, CA),
(UCS, M)
]
tuple_generate_example(edges)
