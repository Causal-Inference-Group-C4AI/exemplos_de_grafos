# %% [markdown]
# # Exemplos de grafos

# %%
from utils.funcoes import generate_example

# %% [markdown]
# ## Exemplos com uma latente por C-Component

# %% [markdown]
# ### Grafo Balke e Pearl

# %%
arestas =  "U1 -> X, U1 -> Y, U2 -> Z, X -> Y, Z -> X"
generate_example(arestas)
# Out:
# 5
# U1 0
# U2 0
# X 2
# Y 2
# Z 2
# U1 X
# U1 Y
# U2 Z
# X Y
# Z X

# %% [markdown]
# ### Grafo Itaú

# %%
arestas = "U1 -> X, U1 -> Y, U2 -> D, U3 -> E, X -> Y, D -> X, D -> Y, E -> D"
generate_example(arestas)
# Out:
# 7
# U1 0
# U2 0
# U3 0
# X 2
# Y 2
# D 2
# E 2
# U1 X
# U1 Y
# U2 D
# U3 E
# X Y
# D X
# D Y
# E D

# %% [markdown]
# ### Grafo exemplo algoritmo

# %%
arestas = "Ux -> X, Ux -> Y, Ur -> M, Ur -> R, M -> R, X -> R, R -> Y, X -> Y"
generate_example(arestas)
# Out:
# 6
# Ux 0
# Ur 0
# X 2
# Y 2
# M 2
# R 2
# Ux X
# Ux Y
# Ur M
# Ur R
# M R
# X R
# R Y
# X Y

# %% [markdown]
# ### Grafo simples

# %%
arestas = "U1 -> X, U1 -> Y, X -> Y"
generate_example(arestas)
# Out:
# 3
# U1 0
# X 2
# Y 2
# U1 X
# U1 Y
# X Y

# %% [markdown]
# ### Grafo Balke e Pearl sem poda

# %%
arestas = "U1 -> D, U1 -> Z, U2 -> X, U2 -> Y, U2 -> A, D -> Z, Z -> X, X -> Y"
generate_example(arestas)
# Out:
# 7
# U1 0
# U2 0
# D 2
# Z 2
# X 2
# Y 2
# A 2
# U1 D
# U1 Z
# U2 X
# U2 Y
# U2 A
# D Z
# Z X
# X Y

# %% [markdown]
# ### Grafo dois sistemas lineares

# %%
arestas = "U1 -> X, U1 -> Z, U2 -> W, U2 -> Y, X -> Z, Z -> W, W -> Y"
generate_example(arestas)
# Out:
# 6
# U1 0
# U2 0
# X 2
# Z 2
# W 2
# Y 2
# U1 X
# U1 Z
# U2 W
# U2 Y
# X Z
# Z W
# W Y

# %% [markdown]
# ### Grafo ineficiente

# %%
arestas = "UX -> X, UZ -> Z, UY -> Y, X -> Z, Z -> Y"
generate_example(arestas)
# Out:
# 6
# UX 0
# UZ 0
# UY 0
# X 2
# Z 2
# Y 2
# UX X
# UZ Z
# UY Y
# X Z
# Z Y

# %% [markdown]
# ### Grafo com mediador

# %%
arestas = "U1 -> X, U1 -> Y, U2 -> W, X -> W, W -> Y, X -> Y"
generate_example(arestas)
# Out:
# 5
# U1 0
# U2 0
# X 2
# Y 2
# W 2
# U1 X
# U1 Y
# U2 W
# X W
# W Y
# X Y

# %% [markdown]
# ### Grafo com colisor

# %%
arestas = "U1 -> X, U1 -> Y, U2 -> Z, X -> Y, Z -> Y"
generate_example(arestas)
# Out:
# 5
# U1 0
# U2 0
# X 2
# Y 2
# Z 2
# U1 X
# U1 Y
# U2 Z
# X Y
# Z Y

# %% [markdown]
# ### Grafo COMPAS

# %%
arestas = """
U1 -> X,
U1 -> Z1,
U2 -> D,
U2 -> Y,
U3 -> J,
U3 -> P,
X -> J,
X -> P,
X -> D,
X -> Y,
J -> P,
J -> D,
J -> Y,
P -> D,
D -> Y,
Z1 -> J,
Z1 -> P,
Z1 -> D,
Z1 -> Y,
Z2 -> J,
Z2 -> P,
Z2 -> D,
Z2 -> Y
"""
generate_example(arestas)
# Out:
# 10
# U1 0
# U2 0
# U3 0
# X 2
# Z1 2
# D 2
# Y 2
# J 2
# P 2
# Z2 2
# U1 X
# U1 Z1
# U2 D
# U2 Y
# U3 J
# U3 P
# X J
# X P
# X D
# X Y
# J P
# J D
# J Y
# P D
# D Y
# Z1 J
# Z1 P
# Z1 D
# Z1 Y
# Z2 J
# Z2 P
# Z2 D
# Z2 Y

# %% [markdown]
# ## Exemplos com mais de uma latente por C-Component

# %% [markdown]
# ### Grafo exemplo 7

# %%
arestas = "U1 -> X, U1 -> Y, U2 -> X, U3 -> X, X -> Y"
generate_example(arestas)
# Out:
# 5
# U1 0
# U2 0
# U3 0
# X 2
# Y 2
# U1 X
# U1 Y
# U2 X
# U3 X
# X Y
